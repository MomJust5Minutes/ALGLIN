# %%
import numpy as np

# %%
v = np.array([4, 5, 6])
print(v)
# Out:
# [4 5 6]

# %%
v.ndim
# Out:
# 1

# %%
v[0]
# Out:
# 4

# %%
v[1]
# Out:
# 5

# %%
v[0:2]
# Out:
# array([4, 5])

# %%
v[0:3]
# Out:
# array([4, 5, 6])

# %%
print(v)
# Out:
# [4 5 6]

# %%
u=np.array([1,2,3])

# %%
for i in range(3):
  print(u[i])
# Out:
# 1
# 2
# 3

# %%
soma = 0
for i in range(3):
  soma = soma + u[i]

# %%
print(soma)
# Out:
# 6

# %%
w = np.array([10, 15, 20, 30, 50])

# %%
soma2 = 0
for i in range(5):
  soma2 = soma2 + w[i]
  print(soma2)
# Out:
# 10
# 25
# 45
# 75
# 125

# %%
soma2 = 0
for i in range(5):
  soma2 = soma2 + w[i]
print(soma2)
# Out:
# 125

# %%
print(u)
print(v)
# Out:
# [1 2 3]
# [4 5 6]

# %%
produto_esc = 0
for i in range(3):
  produto_esc = produto_esc + u[i]*v[i]
print(produto_esc)
# Out:
# 32

# %%
A = np.array([[1, 2],
              [0, -1], 
              [4, 6]])
print(A)
# Out:
# [[ 1  2]
#  [ 0 -1]
#  [ 4  6]]

# %%
A.ndim
# Out:
# 2

# %%
A.shape
# Out:
# (3, 2)

# %%
A[1,1]
# Out:
# -1

# %%
A[2,1]
# Out:
# 6

# %%
A[1:3,0:2]
# Out:
# array([[ 0, -1],
#        [ 4,  6]])

# %%
A = np.array([[2,3],
              [1, 0],
              [5, 4]])

# %%
B = np.array([[6, 7],
              [8, 9]])

# %%
print(A)
print(B)
# Out:
# [[2 3]
#  [1 0]
#  [5 4]]
# [[6 7]
#  [8 9]]

# %%
for i in range(3):
  for j in range(2):
    print(A[i,j])
# Out:
# 2
# 3
# 1
# 0
# 5
# 4
